# %%
import numpy as np
import pandas as pd
import re

from MetadataCollector import metadata_xml
from xmlCleanDelete import extract_meta

# %%
book_id = pd.read_csv("data.csv")
book_id.shape
# Out:
# (180060, 1)

# %%
books_pt1 = list(book_id.iloc[:100, 0])
books_pt1
# Out:
# [10572,
#  22039251,
#  1869,
#  6469165,
#  1466455,
#  1282954,
#  13539044,
#  6101718,
#  7967,
#  375802,
#  13542948,
#  74648,
#  463003,
#  6334,
#  6277178,
#  6493208,
#  4667024,
#  7170627,
#  7937843,
#  256566,
#  378,
#  6534932,
#  35982,
#  6892870,
#  5060378,
#  2429135,
#  7260188,
#  6148028,
#  2767052,
#  6482399,
#  2830067,
#  3153910,
#  3247408,
#  4929705,
#  294047,
#  6411961,
#  6202342,
#  21686,
#  5171894,
#  425123,
#  21671,
#  480479,
#  347143,
#  2187,
#  1142147,
#  19063,
#  9010,
#  2728527,
#  294045,
#  4953,
#  128029,
#  77203,
#  5174,
#  1454115,
#  1622,
#  178599,
#  254044,
#  98202,
#  186632,
#  921576,
#  600109,
#  428077,
#  24280,
#  2277444,
#  294044,
#  98807,
#  183822,
#  294042,
#  1178039,
#  1162543,
#  428263,
#  74824,
#  43763,
#  4989,
#  294043,
#  49041,
#  41865,
#  210404,
#  4588,
#  3950967,
#  248787,
#  101299,
#  48328,
#  146064,
#  1557573,
#  1609454,
#  19501,
#  294046,
#  92147,
#  4214,
#  33441,
# ...

# %%
metadata_xml(books_pt1)

# %%
extract_meta()
# Out:
# {'book_id': [7967,
#   23420,
#   2277444,
#   62220,
#   17780,
#   1388894,
#   428263,
#   5060378,
#   92147,
#   41865,
#   363204,
#   186632,
#   183822,
#   21686,
#   294047,
#   37470,
#   74648,
#   101299,
#   43763,
#   4953,
#   43641,
#   4588,
#   146064,
#   98807,
#   24280,
#   6277178,
#   22039251,
#   1282954,
#   1466455,
#   316994,
#   2429135,
#   5133061,
#   294045,
#   210404,
#   1622,
#   16183,
#   1557573,
#   10572,
#   425123,
#   921576,
#   3247408,
#   463003,
#   21671,
#   6148028,
#   1388949,
#   9010,
#   294042,
#   294044,
#   6411961,
#   28920,
#   23422,
#   7937843,
#   1609454,
#   1653937,
#   128029,
#   193755,
#   1974566,
#   428077,
#   77203,
#   1178039,
#   6469165,
#   98202,
#   4667024,
#   6892870,
#   1454115,
#   480479,
#   2728527,
#   512981,
#   375802,
#   4929705,
#   74824,
#   19501,
#   256566,
#   10441,
#   248787,
#   6534932,
#   3153910,
#   254044,
#   4670201,
#   1142147,
#   1162543,
#   40117,
# ...

# %%
df = pd.DataFrame.from_dict(metadata)

# %%
df.head()

# %%
df.shape

# %% [markdown]
# ### Wuuuuuuuusaaaa

# %%
df = munging(df)

# %%
df
